# %%
import pandas as pd

## importing libraries to plot the wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
with open("text.txt", 'r', encoding="utf-8") as file:
    t = file.readlines()

print(t)

# %%
stopwords = set(STOPWORDS)
badwords = {'Artigo', 'e', 'Emenda', 'Inciso', 'Constitucional', 'nº', 'II', 'I', 'Art', 'da lei'}

## deleting the useless words on plot
stopwords.update(badwords)

## plot parameters
wordcloud = WordCloud(background_color='black', 
                      stopwords=stopwords, 
                      max_words=100, 
                      max_font_size=50, 
                      random_state=42).generate("".join(t))


## Plot
print(wordcloud) 
plt.figure(figsize=(10,5)) 
fig = plt.figure(1) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000028098863AF0>
